# %% [markdown]
# ## Linear Classifier in TensorFlow
# Using Low Level API in Eager Execution mode

# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
tf.enable_eager_execution()

# %%
#Enable Eager Execution if using tensflow version < 2.0
#From tensorflow v2.0 onwards, Eager Execution will be enabled by default

# %% [markdown]
# ### Collect Data

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
data1 = pd.read_csv("/gdrive/My Drive/Colab Notebooks/DeepLearning/LAB6/prices.csv")

# %% [markdown]
# ### Check all columns in the dataset

# %%
data1.columns
# Out:
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')

# %% [markdown]
# ### Drop columns `date` and  `symbol`

# %%
data1.drop(columns=['date','symbol'], inplace=True)

# %%
data1.columns
# Out:
# Index(['open', 'close', 'low', 'high', 'volume'], dtype='object')

# %%
data.head()
# Out:
#          open       close         low        high  volume
# 0  123.430000  125.839996  122.309998  126.250000  2.1636
# 1  125.239998  119.980003  119.940002  125.540001  2.3864
# 2  116.379997  114.949997  114.930000  119.739998  2.4895
# 3  115.480003  116.620003  113.500000  117.440002  2.0063
# 4  117.010002  114.970001  114.089996  117.330002  1.4086

# %%
data1.shape
# Out:
# (851264, 5)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 5 columns):
# open      851264 non-null float64
# close     851264 non-null float64
# low       851264 non-null float64
# high      851264 non-null float64
# volume    851264 non-null float64
# dtypes: float64(5)
# memory usage: 32.5 MB

# %%
data1.describe().transpose()
# Out:
#            count          mean  ...           75%           max
# open    851264.0  7.083699e+01  ...  7.988000e+01  1.584440e+03
# close   851264.0  7.085711e+01  ...  7.989000e+01  1.578130e+03
# low     851264.0  7.011841e+01  ...  7.911000e+01  1.549940e+03
# high    851264.0  7.154348e+01  ...  8.061000e+01  1.600930e+03
# volume  851264.0  5.415113e+06  ...  5.222500e+06  8.596434e+08
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Consider only first 1000 rows in the dataset for building feature set and target set
# Target 'Volume' has very high values. Divide 'Volume' by 1000,000

# %%
data=data1.head(1000)

# %%
import numpy as np

# %%
data['volume'] = [np.divide(x,1000000) for x in data['volume']]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data['volume'][0]
# Out:
# 2.1636

# %%
data1['volume'][0]
# Out:
# 2.1636

# %% [markdown]
# ### Divide the data into train and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
X= np.array(data.drop(columns='volume'))
y= np.array(data['volume'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2324)

# %% [markdown]
# #### Convert Training and Test Data to numpy float32 arrays

# %%
X_train.shape
# Out:
# (800, 4)

# %%
X_test.shape
# Out:
# (200, 4)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_test = y_test.astype('float32')
y_train = y_train.astype('float32')

# %% [markdown]
# ### Normalize the data
# You can use Normalizer from sklearn.preprocessing

# %%
from sklearn.preprocessing import Normalizer

# %%
scale = Normalizer()

# %%
X_train_z = scale.fit_transform(X_train)

# %%
X_test_z= scale.fit_transform(X_test)

# %%
X_train_z.shape
# Out:
# (800, 4)

# %%
X_train_z = X_train_z.astype('float32')
X_test_z = X_test_z.astype('float32')
y_test = y_test.astype('float32')
y_train = y_train.astype('float32')

# %% [markdown]
# ## Building the Model in tensorflow

# %% [markdown]
# 1.Define Weights and Bias, use tf.zeros to initialize weights and Bias

# %%
#We are initializing weights and Bias with Zero
w = tf.zeros(shape=(4,1))
b = tf.zeros(shape=(1))

# %% [markdown]
# 2.Define a function to calculate prediction

# %%
def prediction(x, w, b):
    
    xw_matmul = tf.matmul(x, w)
    y = tf.add(xw_matmul, b)
    
    return y

# %% [markdown]
# 3.Loss (Cost) Function [Mean square error]

# %%
def loss(y_actual, y_predicted):
    
    diff = y_actual - y_predicted
    sqr = tf.square(diff)
    avg = tf.reduce_mean(sqr)
    
    return avg

# %% [markdown]
# 4.Function to train the Model
#
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
    
    #Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        
        t.watch([w,b])
        
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    #Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    
    #Update Weights and Bias
    w = w - learning_rate*dw
    b = b - learning_rate*db
    
    return w, b

# %% [markdown]
# ## Train the model for 100 epochs
# 1. Observe the training loss at every iteration
# 2. Observe Train loss at every 5th iteration

# %%
   for i in range(100):
    
    w, b = train(X_train_z, y_train, w, b)
    print('Current Loss on iteration', i, loss(y_train, prediction(X_train_z, w, b)).numpy())
# Out:
# Current Loss on iteration 0 195.37025
# Current Loss on iteration 1 193.4514
# Current Loss on iteration 2 191.68297
# Current Loss on iteration 3 190.0532
# Current Loss on iteration 4 188.5512
# Current Loss on iteration 5 187.16695
# Current Loss on iteration 6 185.89122
# Current Loss on iteration 7 184.7155
# Current Loss on iteration 8 183.63194
# Current Loss on iteration 9 182.63338
# Current Loss on iteration 10 181.71306
# Current Loss on iteration 11 180.8649
# Current Loss on iteration 12 180.08325
# Current Loss on iteration 13 179.36287
# Current Loss on iteration 14 178.69897
# Current Loss on iteration 15 178.08711
# Current Loss on iteration 16 177.52322
# Current Loss on iteration 17 177.00356
# Current Loss on iteration 18 176.52463
# Current Loss on iteration 19 176.08322
# Current Loss on iteration 20 175.67644
# Current Loss on iteration 21 175.30154
# Current Loss on iteration 22 174.95604
# Current Loss on iteration 23 174.63762
# Current Loss on iteration 24 174.34418
# Current Loss on iteration 25 174.07373
# Current Loss on iteration 26 173.8245
# Current Loss on iteration 27 173.59477
# Current Loss on iteration 28 173.38309
# Current Loss on iteration 29 173.18797
# Current Loss on iteration 30 173.0082
# Current Loss on iteration 31 172.84247
# Current Loss on iteration 32 172.68974
# Current Loss on iteration 33 172.54903
# Current Loss on iteration 34 172.41933
# Current Loss on iteration 35 172.29977
# Current Loss on iteration 36 172.1896
# Current Loss on iteration 37 172.08806
# Current Loss on iteration 38 171.99449
# Current Loss on iteration 39 171.90825
# Current Loss on iteration 40 171.82878
# Current Loss on iteration 41 171.75554
# Current Loss on iteration 42 171.68805
# Current Loss on iteration 43 171.62584
# Current Loss on iteration 44 171.56848
# Current Loss on iteration 45 171.51566
# Current Loss on iteration 46 171.46695
# Current Loss on iteration 47 171.42207
# Current Loss on iteration 48 171.38074
# Current Loss on iteration 49 171.3426
# Current Loss on iteration 50 171.3075
# Current Loss on iteration 51 171.27512
# Current Loss on iteration 52 171.24527
# Current Loss on iteration 53 171.21776
# Current Loss on iteration 54 171.19243
# Current Loss on iteration 55 171.16907
# Current Loss on iteration 56 171.14755
# Current Loss on iteration 57 171.12772
# Current Loss on iteration 58 171.10942
# Current Loss on iteration 59 171.09258
# Current Loss on iteration 60 171.07706
# Current Loss on iteration 61 171.06274
# Current Loss on iteration 62 171.04956
# Current Loss on iteration 63 171.03741
# Current Loss on iteration 64 171.0262
# Current Loss on iteration 65 171.01587
# Current Loss on iteration 66 171.00636
# Current Loss on iteration 67 170.9976
# Current Loss on iteration 68 170.98952
# Current Loss on iteration 69 170.98206
# Current Loss on iteration 70 170.9752
# Current Loss on iteration 71 170.96887
# Current Loss on iteration 72 170.96304
# Current Loss on iteration 73 170.95767
# Current Loss on iteration 74 170.95273
# Current Loss on iteration 75 170.94817
# Current Loss on iteration 76 170.94397
# Current Loss on iteration 77 170.94008
# Current Loss on iteration 78 170.9365
# Current Loss on iteration 79 170.93323
# Current Loss on iteration 80 170.93018
# Current Loss on iteration 81 170.92738
# Current Loss on iteration 82 170.92482
# Current Loss on iteration 83 170.92245
# Current Loss on iteration 84 170.92026
# Current Loss on iteration 85 170.91823
# Current Loss on iteration 86 170.91638
# Current Loss on iteration 87 170.91467
# Current Loss on iteration 88 170.9131
# Current Loss on iteration 89 170.91162
# Current Loss on iteration 90 170.9103
# Current Loss on iteration 91 170.90906
# Current Loss on iteration 92 170.90791
# Current Loss on iteration 93 170.90686
# Current Loss on iteration 94 170.90588
# Current Loss on iteration 95 170.905
# Current Loss on iteration 96 170.90417
# Current Loss on iteration 97 170.90344
# Current Loss on iteration 98 170.90273
# Current Loss on iteration 99 170.90207

# %% [markdown]
# ### Get the shapes and values of W and b

# %%
#Check Weights and Bias
print('Weights:\n', w.numpy())
print('Bias:\n',b.numpy())
# Out:
# Weights:
#  [[1.2649972]
#  [1.2692019]
#  [1.251856 ]
#  [1.2802608]]
# Bias:
#  [2.533298]

# %% [markdown]
# ### Model Prediction on 1st Examples in Test Dataset

# %%
X_test_z[0]
# Out:
# array([0.50227785, 0.49966323, 0.49195227, 0.50600046], dtype=float32)

# %%
X_test_z.shape
# Out:
# (200, 4)

# %%
prediction = prediction(X_test_z[0:1], w,b)

# %%
prediction
# Out:
# <tf.Tensor: id=14193, shape=(1, 1), dtype=float32, numpy=array([[5.066518]], dtype=float32)>

# %%
y_test[0]
# Out:
# 0.4599

# %% [markdown]
# ## Classification using tf.Keras
#
# In this exercise, we will build a Deep Neural Network using tf.Keras. We will use Iris Dataset for this exercise.

# %% [markdown]
# ### Load the given Iris data using pandas (Iris.csv)

# %%
data2 = pd.read_csv("/gdrive/My Drive/Colab Notebooks/DeepLearning/LAB6/Iris.csv")

# %% [markdown]
# ### Target set has different categories. So, Label encode them. And convert into one-hot vectors using get_dummies in pandas.

# %%
data2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
data2['Species']= label_encoder.fit_transform(data2['Species'])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %% [markdown]
# ### Splitting the data into feature set and target set

# %%
X1= np.array(data2.drop(columns=['Species','Id']))

# %%
y1 = np.array(data2['Species'])

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,test_size=0.2,random_state=2324)

# %%
X1_train_z = scale.fit_transform(X1_train)

# %%
X1_test_z = scale.fit_transform(X1_test)

# %%
y1_train = tf.keras.utils.to_categorical(y1_train, num_classes=3)
y1_test = tf.keras.utils.to_categorical(y1_test, num_classes=3)

# %%
print(y1_train.shape)
print('First 2 examples now are: ', y1_train[0:2])
# Out:
# (120, 3)
# First 2 examples now are:  [[0. 0. 1.]
#  [0. 1. 0.]]

# %%
X1_train_z = X1_train_z.astype('float32')
X1_test_z = X1_test_z.astype('float32')
y1_test = y1_test.astype('float32')
y1_train = y1_train.astype('float32')

# %% [markdown]
# ###  Building Model in tf.keras
#
# Build a Linear Classifier model  <br>
# 1.  Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3<br>
# 2. Apply Softmax on Dense Layer outputs <br>
# 3. Use SGD as Optimizer
# 4. Use categorical_crossentropy as loss function

# %%
X1_test_z.shape
# Out:
# (30, 4)

# %%
#Initialize Sequential model
model = tf.keras.models.Sequential()

# %%
#Normalize the data
model.add(tf.keras.layers.BatchNormalization())

# %%
#Add Dense Layer which provides 10 Outputs after applying softmax
model.add(tf.keras.layers.Dense(3, input_shape=(4,),activation='softmax'))

# %%
#Comile the model
model.compile(optimizer='sgd', loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %% [markdown]
# ### Model Training

# %%
model.fit(X1_train_z, y1_train, 
          validation_data=(X1_test_z, y1_test), 
          epochs=100,
          batch_size=X1_train_z.shape[0])
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/100
# 120/120 [==============================] - 1s 6ms/sample - loss: 1.1182 - acc: 0.3417 - val_loss: 1.2295 - val_acc: 0.3000
# Epoch 2/100
# 120/120 [==============================] - 0s 131us/sample - loss: 1.1164 - acc: 0.3417 - val_loss: 1.2282 - val_acc: 0.3000
# Epoch 3/100
# 120/120 [==============================] - 0s 111us/sample - loss: 1.1146 - acc: 0.3417 - val_loss: 1.2269 - val_acc: 0.3000
# Epoch 4/100
# 120/120 [==============================] - 0s 145us/sample - loss: 1.1128 - acc: 0.3417 - val_loss: 1.2256 - val_acc: 0.3000
# Epoch 5/100
# 120/120 [==============================] - 0s 142us/sample - loss: 0.9828 - acc: 0.4000 - val_loss: 1.1399 - val_acc: 0.3000
# Epoch 85/100
# 120/120 [==============================] - 0s 139us/sample - loss: 0.9815 - acc: 0.4167 - val_loss: 1.1390 - val_acc: 0.3000
# Epoch 86/100
# 120/120 [==============================] - 0s 100us/sample - loss: 0.9801 - acc: 0.4250 - val_loss: 1.1380 - val_acc: 0.3000
# Epoch 87/100
# 120/120 [==============================] - 0s 141us/sample - loss: 0.9787 - acc: 0.4500 - val_loss: 1.1371 - val_acc: 0.3000
# Epoch 88/100
# 120/120 [==============================] - 0s 131us/sample - loss: 0.9774 - acc: 0.4667 - val_loss: 1.1361 - val_acc: 0.3000
# Epoch 89/100
# 120/120 [==============================] - 0s 139us/sample - loss: 0.9760 - acc: 0.4750 - val_loss: 1.1352 - val_acc: 0.3000
# Epoch 90/100
# 120/120 [==============================] - 0s 139us/sample - loss: 0.9747 - acc: 0.4833 - val_loss: 1.1342 - val_acc: 0.3000
# Epoch 91/100
# 120/120 [==============================] - 0s 119us/sample - loss: 0.9733 - acc: 0.5000 - val_loss: 1.1333 - val_acc: 0.3000
# Epoch 92/100
# 120/120 [==============================] - 0s 204us/sample - loss: 0.9720 - acc: 0.5000 - val_loss: 1.1323 - val_acc: 0.3000
# Epoch 93/100
# 120/120 [==============================] - 0s 123us/sample - loss: 0.9707 - acc: 0.5083 - val_loss: 1.1314 - val_acc: 0.3000
# Epoch 94/100
# 120/120 [==============================] - 0s 155us/sample - loss: 0.9693 - acc: 0.5083 - val_loss: 1.1304 - val_acc: 0.3000
# Epoch 95/100
# 120/120 [==============================] - 0s 146us/sample - loss: 0.9680 - acc: 0.5167 - val_loss: 1.1295 - val_acc: 0.3000
# Epoch 96/100
# 120/120 [==============================] - 0s 153us/sample - loss: 0.9667 - acc: 0.5167 - val_loss: 1.1285 - val_acc: 0.3000
# Epoch 97/100
# 120/120 [==============================] - 0s 135us/sample - loss: 0.9654 - acc: 0.5250 - val_loss: 1.1276 - val_acc: 0.3000
# Epoch 98/100
# 120/120 [==============================] - 0s 173us/sample - loss: 0.9641 - acc: 0.5333 - val_loss: 1.1266 - val_acc: 0.3000
# Epoch 99/100
# 120/120 [==============================] - 0s 144us/sample - loss: 0.9629 - acc: 0.5333 - val_loss: 1.1257 - val_acc: 0.3000
# Epoch 100/100
# 120/120 [==============================] - 0s 138us/sample - loss: 0.9616 - acc: 0.5417 - val_loss: 1.1247 - val_acc: 0.3000

# %% [markdown]
# ### Model Prediction

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo multiple                  16
# _________________________________________________________________
# dense (Dense)                multiple                  15
# _________________________________________________________________
# dense_1 (Dense)              multiple                  12
# =================================================================
# Total params: 43
# Trainable params: 35
# Non-trainable params: 8
# _________________________________________________________________

# %% [markdown]
# ### Save the Model

# %%
model.save('mnist_lc.h5')

# %% [markdown]
# ### Build and Train a Deep Neural network with 2 hidden layer  - Optional - For Practice
#
# Does it perform better than Linear Classifier? What could be the reason for difference in performance?
